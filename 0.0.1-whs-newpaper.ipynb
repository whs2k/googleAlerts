# %%
import newspaper

# %%
hb_paper = newspaper.build('https://www.ebay.com/trending')
for article in hb_paper.articles:
    print(article.url)
# Out:
# https://www.ebay.com/b/Collectible-Funko-Bobbleheads-1970-Now/149372/bn_3017826
# https://www.ebay.com/b/Kitchen-Dining-Bar-Supplies/20625/bn_1865564
# https://www.ebay.com/b/Bedding/20444/bn_1864382
# https://www.ebay.com/b/Major-Appliances-Parts-Accessories/20710/bn_1865562
# https://www.ebay.com/b/Archery-Equipment/20835/bn_1971493
# https://www.ebay.com/b/Preschool-Toys-Pretend-Play/19169/bn_1864380
# https://www.ebay.com/b/Packaging-Shipping/19273/bn_1865376
# https://www.ebay.com/itm/2018-Full-Body-Massage-Chair-3yrs-Warranty-Recliner-Shiatsu-Heat-Zero-Gravity/273207096560?_trkparms=pageci%3A783e2a9d-f114-11e8-b5ea-74dbd18049ab%7Cparentrq%3A4d79c59c1670ac1e6c0daad9fff03489%7Ciid%3A1
# https://www.ebay.com/rpp/eBay-today/VQ-112418-Home-and-Garden-Cyber-Monday
# https://www.ebay.com/v/allcategories
# https://www.ebayinc.com/stories/news/
# http://community.ebay.com/plugins/common/feature/oauth2sso_v2/sso_login_redirect?referer=https%3A%2F%2Fcommunity.ebay.com%2F
# ...

# %%
urls = [article.url for article in hb_paper.articles]
texts = [article.text for article in hb_paper.articles]
print(len(urls))
# Out:
# 0

# %%
texts[0]
# Out:
# ''

# %%
for article in cnn_paper.articles:
    print(article.doc)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
